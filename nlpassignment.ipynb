# %% [markdown]
# #Text Generation using LSTM
# >PARTH SAGAR
# >210431117
#
# ## README
# * Note: these execution steps are recommended for GOOGLE COLAB
# ### Steps to replicate:
# 1. Upload file.txt file to your runtime.
# 2. Run the first cell for data cleaning and generating doc file for training and testing.
# 3. Training can be done by running the second cell, it is recommended to download files generated here in runtime and model as if runtime disconnects they can be used for testing and future use.
# 4. for testing the model needs to be uploaded (if training and testing aren't done in sequence) , along with the file sequences.txt provided in the folder.

# %%
#to process the data files
import string 
 
# loading the document in the memory
def load_doc(filename):
	# opening the file in read only mode
	document = open(filename, 'r')
	# reading the text data
	data = document.read()
	# closing the file
	document.close()
	return data
 
# turning the document into tokens after cleaning
def clean_doc(file):
	# replacing '--' with spaces ' '
	file = file.replace('--', ' ')
	# tokens are being created after splitting on spaces
	tokens = file.split()
	# removing the punctuations by creating a translation table
	table = str.maketrans('', '', string.punctuation)
	tokens = [w.translate(table) for w in tokens]
	# removing all the non alphabetic characters
	tokens = [word for word in tokens if word.isalpha()]
	# converting all text into lower case
	tokens = [word.lower() for word in tokens]
	return tokens
 
# saving all the tokens in a file with one dialog being fed in one line
def save_doc(lines, filename):
  # forming the data line by line
	data = '\n'.join(lines)
  # opening file in write mode.
	file = open(filename, 'w')
  # writing the data in the file
	file.write(data)
  # closing the file 
	file.close()
 
# loading the document
in_filename = "/content/file.txt"
doc = load_doc(in_filename)
# printing the first 200 characters
print(doc[:200])
 
# cleaning the loaded document
tokens = clean_doc(doc)
# printing the cleaned document that is first 200 words
print(tokens[:200])
print('Total Tokens: %d' % len(tokens))
print('Unique Tokens: %d' % len(set(tokens)))
 
# organize into sequences of tokens
length = 50 + 1
sequences = list()
for i in range(length, len(tokens)):
	# select sequence of tokens
	seq = tokens[i-length:i]
	# convert into a line
	line = ' '.join(seq)
	# storing them as a list of sequences
	sequences.append(line)
print('Total Sequences: %d' % len(sequences))
 
# saving sequences to a file
out_filename = 'sequences.txt'
save_doc(sequences, out_filename)
# Out:
# The Project Gutenberg EBook of Poirot Investigates, by Agatha Christie
#
# This eBook is for the use of anyone anywhere in the United States and most
# other parts of the world at no cost and with almost n
# ['the', 'project', 'gutenberg', 'ebook', 'of', 'poirot', 'investigates', 'by', 'agatha', 'christie', 'this', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'united', 'states', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', 'you', 'may', 'copy', 'it', 'give', 'it', 'away', 'or', 'reuse', 'it', 'under', 'the', 'terms', 'of', 'the', 'project', 'gutenberg', 'license', 'included', 'with', 'this', 'ebook', 'or', 'online', 'at', 'wwwgutenbergorg', 'if', 'you', 'are', 'not', 'located', 'in', 'the', 'united', 'states', 'youll', 'have', 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using', 'this', 'ebook', 'title', 'poirot', 'investigates', 'author', 'agatha', 'christie', 'release', 'date', 'january', 'ebook', 'language', 'english', 'character', 'set', 'encoding', 'start', 'of', 'this', 'project', 'gutenberg', 'ebook', 'poirot', 'investigates', 'produced', 'by', 'an', 'anonymous', 'project', 'gutenberg', 'volunteer', 'poirot', 'investigates', 'by', 'the', 'same', 'author', 'the', 'mysterious', 'affair', 'at', 'styles', 'the', 'secret', 'adversary', 'the', 'murder', 'on', 'the', 'links', 'the', 'bodley', 'head', 'poirot', 'investigates', 'by', 'agatha', 'christie', 'london', 'john', 'lane', 'the', 'bodley', 'head', 'limited', 'first', 'published', 'in', 'great', 'britain', 'by', 'john', 'lane', 'company', 'the', 'bodley', 'head', 'limited', 'copyright', 'agatha', 'christie', 'limited', 'contents', 'i', 'the', 'adventure', 'of', 'western', 'ii', 'the', 'tragedy', 'at', 'marsdon', 'manor', 'iii', 'the', 'adventure', 'of', 'the', 'cheap', 'flat', 'iv', 'the', 'mystery', 'of', 'lodge', 'v', 'the', 'million', 'dollar']
# Total Tokens: 51057
# Unique Tokens: 5916
# Total Sequences: 51006

# %%
from numpy import array
from pickle import dump
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding
 
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text
 
# loading the file
in_filename = 'sequences.txt'
doc = load_doc(in_filename)
# creating lines from document 
lines = doc.split('\n')
 
# encoding unique words in categories
tokenizer = Tokenizer()
# creating tokens of words in lines
tokenizer.fit_on_texts(lines)
# creating sequences as numeric array 
sequences = tokenizer.texts_to_sequences(lines)
# vocabulary size is the total unique words
vocab_size = len(tokenizer.word_index) + 1
 
# separate into input and output
# converting sequences into array
sequences = array(sequences)
# taking all the previous words a input and last word as output
X, y = sequences[:,:-1], sequences[:,-1]
# converting Y to categorical which will give us the y as encoded value from vocab size
y = to_categorical(y, num_classes=vocab_size)
seq_length = X.shape[1]
 
# defining the  model
model = Sequential()
# embedding layer to take the whole vocab as input and give output of sequence length and total words that is 50
model.add(Embedding(vocab_size, 50, input_length=seq_length))
# adding LSTM layer return sequences has to be true to add another LSTM layer
model.add(LSTM(250, return_sequences=True))
# adding another LSTM layer
model.add(LSTM(100))
# adding a hidden layer
model.add(Dense(100, activation='relu'))
# output layer with whole vocabulary
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# compiling model with categorical crossentopy loss and adam optimiser
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fitting the model
model.fit(X, y, batch_size=128, epochs=250)
 
# saving the model as a h5 file
model.save('model.h5')
# saving the tokenizer as a pickle file
dump(tokenizer, open('tokenizer.pkl', 'wb'))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 50)            295850
#
#  lstm (LSTM)                 (None, 50, 250)           301000
#
#  lstm_1 (LSTM)               (None, 100)               140400
#
#  dense (Dense)               (None, 100)               10100
#
#  dense_1 (Dense)             (None, 5917)              597617
#
# =================================================================
# Total params: 1,344,967
# Trainable params: 1,344,967
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/250
# 399/399 [==============================] - 17s 20ms/step - loss: 6.7830 - accuracy: 0.0620
# Epoch 2/250
# 399/399 [==============================] - 8s 20ms/step - loss: 6.5310 - accuracy: 0.0624
# Epoch 3/250
# 399/399 [==============================] - 8s 21ms/step - loss: 6.4182 - accuracy: 0.0624
# Epoch 4/250
# 399/399 [==============================] - 10s 24ms/step - loss: 6.2081 - accuracy: 0.0691
# Epoch 5/250
# 399/399 [==============================] - 8s 20ms/step - loss: 6.0458 - accuracy: 0.0778
# Epoch 6/250
# 399/399 [==============================] - 8s 20ms/step - loss: 5.9021 - accuracy: 0.0876
# Epoch 7/250
# 399/399 [==============================] - 8s 20ms/step - loss: 5.7683 - accuracy: 0.0949
# Epoch 8/250
# 399/399 [==============================] - 8s 20ms/step - loss: 5.6464 - accuracy: 0.1014
# Epoch 9/250
# 399/399 [==============================] - 8s 20ms/step - loss: 5.5503 - accuracy: 0.1089
# Epoch 10/250
# 399/399 [==============================] - 8s 20ms/step - loss: 5.4695 - accuracy: 0.1105
# Epoch 11/250
# 399/399 [==============================] - 8s 20ms/step - loss: 5.4393 - accuracy: 0.1144
# Epoch 12/250
# 399/399 [==============================] - 8s 21ms/step - loss: 5.3434 - accuracy: 0.1176
# Epoch 13/250
# 399/399 [==============================] - 8s 20ms/step - loss: 5.2773 - accuracy: 0.1216
# Epoch 14/250
# 399/399 [==============================] - 8s 20ms/step - loss: 5.2378 - accuracy: 0.1257
# Epoch 15/250
# 399/399 [==============================] - 8s 21ms/step - loss: 5.1604 - accuracy: 0.1302
# Epoch 16/250
# 399/399 [==============================] - 8s 20ms/step - loss: 5.0803 - accuracy: 0.1346
# Epoch 17/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.9853 - accuracy: 0.1407
# Epoch 18/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.9192 - accuracy: 0.1415
# Epoch 19/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.8765 - accuracy: 0.1423
# Epoch 20/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.8082 - accuracy: 0.1460
# Epoch 21/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.7180 - accuracy: 0.1511
# Epoch 22/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.6337 - accuracy: 0.1568
# Epoch 23/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.5728 - accuracy: 0.1588
# Epoch 24/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.5769 - accuracy: 0.1606
# Epoch 25/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.6198 - accuracy: 0.1613
# Epoch 26/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.5419 - accuracy: 0.1652
# Epoch 27/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.4837 - accuracy: 0.1680
# Epoch 28/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.4226 - accuracy: 0.1708
# Epoch 29/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.3647 - accuracy: 0.1747
# Epoch 30/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.3090 - accuracy: 0.1788
# Epoch 31/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.2558 - accuracy: 0.1812
# Epoch 32/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.2008 - accuracy: 0.1864
# Epoch 33/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.1534 - accuracy: 0.1894
# Epoch 34/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.1012 - accuracy: 0.1930
# Epoch 35/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.0525 - accuracy: 0.1963
# Epoch 36/250
# 399/399 [==============================] - 8s 20ms/step - loss: 4.0060 - accuracy: 0.2011
# Epoch 37/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.9603 - accuracy: 0.2054
# Epoch 38/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.9118 - accuracy: 0.2099
# Epoch 39/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.8637 - accuracy: 0.2145
# Epoch 40/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.8169 - accuracy: 0.2192
# Epoch 41/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.7729 - accuracy: 0.2234
# Epoch 42/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.7268 - accuracy: 0.2304
# Epoch 43/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.6826 - accuracy: 0.2360
# Epoch 44/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.6371 - accuracy: 0.2399
# Epoch 45/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.5882 - accuracy: 0.2451
# Epoch 46/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.5462 - accuracy: 0.2515
# Epoch 47/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.4991 - accuracy: 0.2567
# Epoch 48/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.4591 - accuracy: 0.2610
# Epoch 49/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.4151 - accuracy: 0.2702
# Epoch 50/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.3703 - accuracy: 0.2745
# Epoch 51/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.3251 - accuracy: 0.2805
# Epoch 52/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.2795 - accuracy: 0.2897
# Epoch 53/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.2361 - accuracy: 0.2953
# Epoch 54/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.1948 - accuracy: 0.3009
# Epoch 55/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.1502 - accuracy: 0.3083
# Epoch 56/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.1073 - accuracy: 0.3149
# Epoch 57/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.0639 - accuracy: 0.3222
# Epoch 58/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.0163 - accuracy: 0.3282
# Epoch 59/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.9722 - accuracy: 0.3374
# Epoch 60/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.9335 - accuracy: 0.3446
# Epoch 61/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.8896 - accuracy: 0.3508
# Epoch 62/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.8493 - accuracy: 0.3585
# Epoch 63/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.8034 - accuracy: 0.3656
# Epoch 64/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.7609 - accuracy: 0.3745
# Epoch 65/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.7211 - accuracy: 0.3799
# Epoch 66/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.6781 - accuracy: 0.3883
# Epoch 67/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.6365 - accuracy: 0.3954
# Epoch 68/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.5937 - accuracy: 0.4037
# Epoch 69/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.5533 - accuracy: 0.4119
# Epoch 70/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.5163 - accuracy: 0.4196
# Epoch 71/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.4735 - accuracy: 0.4276
# Epoch 72/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.4338 - accuracy: 0.4355
# Epoch 73/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.3878 - accuracy: 0.4420
# Epoch 74/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.3604 - accuracy: 0.4456
# Epoch 75/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.3142 - accuracy: 0.4559
# Epoch 76/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.2809 - accuracy: 0.4628
# Epoch 77/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.2389 - accuracy: 0.4696
# Epoch 78/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.1991 - accuracy: 0.4782
# Epoch 79/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.1671 - accuracy: 0.4844
# Epoch 80/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.1244 - accuracy: 0.4943
# Epoch 81/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.0915 - accuracy: 0.5003
# Epoch 82/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.0506 - accuracy: 0.5091
# Epoch 83/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.0139 - accuracy: 0.5162
# Epoch 84/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.9829 - accuracy: 0.5225
# Epoch 85/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.9492 - accuracy: 0.5304
# Epoch 86/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.9086 - accuracy: 0.5382
# Epoch 87/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.8751 - accuracy: 0.5458
# Epoch 88/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.8388 - accuracy: 0.5553
# Epoch 89/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.8058 - accuracy: 0.5626
# Epoch 90/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.7724 - accuracy: 0.5694
# Epoch 91/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.7858 - accuracy: 0.5643
# Epoch 92/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.7065 - accuracy: 0.5828
# Epoch 93/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.6562 - accuracy: 0.5957
# Epoch 94/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.6291 - accuracy: 0.6002
# Epoch 95/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.6035 - accuracy: 0.6068
# Epoch 96/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.5711 - accuracy: 0.6128
# Epoch 97/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.5390 - accuracy: 0.6231
# Epoch 98/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.5085 - accuracy: 0.6291
# Epoch 99/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.4875 - accuracy: 0.6312
# Epoch 100/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.4492 - accuracy: 0.6441
# Epoch 101/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.5004 - accuracy: 0.6276
# Epoch 102/250
# 399/399 [==============================] - 8s 20ms/step - loss: 3.0390 - accuracy: 0.3611
# Epoch 103/250
# 399/399 [==============================] - 8s 20ms/step - loss: 2.1233 - accuracy: 0.4929
# Epoch 104/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.8623 - accuracy: 0.5332
# Epoch 105/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.5709 - accuracy: 0.6125
# Epoch 106/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.5013 - accuracy: 0.6306
# Epoch 107/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.4498 - accuracy: 0.6411
# Epoch 108/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.3518 - accuracy: 0.6693
# Epoch 109/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.2994 - accuracy: 0.6814
# Epoch 110/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.2720 - accuracy: 0.6895
# Epoch 111/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.2452 - accuracy: 0.6947
# Epoch 112/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.2280 - accuracy: 0.6981
# Epoch 113/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.2113 - accuracy: 0.7005
# Epoch 114/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.2135 - accuracy: 0.6978
# Epoch 115/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.3406 - accuracy: 0.6601
# Epoch 116/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.2021 - accuracy: 0.6961
# Epoch 117/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.1242 - accuracy: 0.7199
# Epoch 118/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.0876 - accuracy: 0.7316
# Epoch 119/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.0722 - accuracy: 0.7314
# Epoch 120/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.0631 - accuracy: 0.7334
# Epoch 121/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.0572 - accuracy: 0.7336
# Epoch 122/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.0370 - accuracy: 0.7391
# Epoch 123/250
# 399/399 [==============================] - 8s 20ms/step - loss: 1.0218 - accuracy: 0.7405
# Epoch 124/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.9991 - accuracy: 0.7472
# Epoch 125/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.9765 - accuracy: 0.7532
# Epoch 126/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.9626 - accuracy: 0.7561
# Epoch 127/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.9401 - accuracy: 0.7605
# Epoch 128/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.9120 - accuracy: 0.7690
# Epoch 129/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.9060 - accuracy: 0.7685
# Epoch 130/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.8780 - accuracy: 0.7777
# Epoch 131/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.8559 - accuracy: 0.7821
# Epoch 132/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.8305 - accuracy: 0.7909
# Epoch 133/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.8169 - accuracy: 0.7928
# Epoch 134/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.7886 - accuracy: 0.8015
# Epoch 135/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.7836 - accuracy: 0.7994
# Epoch 136/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.7588 - accuracy: 0.8089
# Epoch 137/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.7464 - accuracy: 0.8115
# Epoch 138/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.7187 - accuracy: 0.8180
# Epoch 139/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.7126 - accuracy: 0.8208
# Epoch 140/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.7013 - accuracy: 0.8226
# Epoch 141/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.6698 - accuracy: 0.8323
# Epoch 142/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.6764 - accuracy: 0.8292
# Epoch 143/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.6381 - accuracy: 0.8393
# Epoch 144/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.6174 - accuracy: 0.8442
# Epoch 145/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.5880 - accuracy: 0.8532
# Epoch 146/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.6259 - accuracy: 0.8391
# Epoch 147/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.6084 - accuracy: 0.8443
# Epoch 148/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.5614 - accuracy: 0.8602
# Epoch 149/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.5246 - accuracy: 0.8714
# Epoch 150/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.5274 - accuracy: 0.8697
# Epoch 151/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.5152 - accuracy: 0.8727
# Epoch 152/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.5360 - accuracy: 0.8631
# Epoch 153/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.5322 - accuracy: 0.8631
# Epoch 154/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.5217 - accuracy: 0.8669
# Epoch 155/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.4777 - accuracy: 0.8813
# Epoch 156/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.4421 - accuracy: 0.8936
# Epoch 157/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.4365 - accuracy: 0.8946
# Epoch 158/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.4453 - accuracy: 0.8899
# Epoch 159/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.4548 - accuracy: 0.8845
# Epoch 160/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.4245 - accuracy: 0.8955
# Epoch 161/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.4272 - accuracy: 0.8944
# Epoch 162/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.4161 - accuracy: 0.8960
# Epoch 163/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.3921 - accuracy: 0.9042
# Epoch 164/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.3649 - accuracy: 0.9132
# Epoch 165/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.3841 - accuracy: 0.9063
# Epoch 166/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.3819 - accuracy: 0.9047
# Epoch 167/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.3749 - accuracy: 0.9073
# Epoch 168/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.3830 - accuracy: 0.9022
# Epoch 169/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.3561 - accuracy: 0.9110
# Epoch 170/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.3401 - accuracy: 0.9161
# Epoch 171/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2929 - accuracy: 0.9321
# Epoch 172/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2754 - accuracy: 0.9394
# Epoch 173/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2957 - accuracy: 0.9292
# Epoch 174/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.3805 - accuracy: 0.8999
# Epoch 175/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.3800 - accuracy: 0.8990
# Epoch 176/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2947 - accuracy: 0.9292
# Epoch 177/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2570 - accuracy: 0.9414
# Epoch 178/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2334 - accuracy: 0.9494
# Epoch 179/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2375 - accuracy: 0.9482
# Epoch 180/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.3490 - accuracy: 0.9079
# Epoch 181/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.3502 - accuracy: 0.9050
# Epoch 182/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2684 - accuracy: 0.9343
# Epoch 183/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2233 - accuracy: 0.9503
# Epoch 184/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2290 - accuracy: 0.9467
# Epoch 185/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2444 - accuracy: 0.9405
# Epoch 186/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2212 - accuracy: 0.9486
# Epoch 187/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2537 - accuracy: 0.9377
# Epoch 188/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2825 - accuracy: 0.9262
# Epoch 189/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2574 - accuracy: 0.9355
# Epoch 190/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2344 - accuracy: 0.9428
# Epoch 191/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.1944 - accuracy: 0.9562
# Epoch 192/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.1906 - accuracy: 0.9570
# Epoch 193/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2426 - accuracy: 0.9384
# Epoch 194/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2619 - accuracy: 0.9309
# Epoch 195/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.2147 - accuracy: 0.9477
# Epoch 196/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.1714 - accuracy: 0.9628
# Epoch 197/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.1683 - accuracy: 0.9633
# Epoch 198/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.1656 - accuracy: 0.9632
# Epoch 199/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.1944 - accuracy: 0.9533
# Epoch 200/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.2487 - accuracy: 0.9334
# Epoch 201/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.2541 - accuracy: 0.9324
# Epoch 202/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.1938 - accuracy: 0.9536
# Epoch 203/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.1426 - accuracy: 0.9708
# Epoch 204/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.1421 - accuracy: 0.9691
# Epoch 205/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.1652 - accuracy: 0.9618
# Epoch 206/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.2711 - accuracy: 0.9241
# Epoch 207/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.2690 - accuracy: 0.9260
# Epoch 208/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.2000 - accuracy: 0.9480
# Epoch 209/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.2799 - accuracy: 0.9249
# Epoch 210/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.1688 - accuracy: 0.9591
# Epoch 211/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0915 - accuracy: 0.9851
# Epoch 212/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0611 - accuracy: 0.9934
# Epoch 213/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0472 - accuracy: 0.9959
# Epoch 214/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0395 - accuracy: 0.9971
# Epoch 215/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0370 - accuracy: 0.9973
# Epoch 216/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.3088 - accuracy: 0.9241
# Epoch 217/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.7587 - accuracy: 0.7907
# Epoch 218/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.2380 - accuracy: 0.9348
# Epoch 219/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.1047 - accuracy: 0.9792
# Epoch 220/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0583 - accuracy: 0.9940
# Epoch 221/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0386 - accuracy: 0.9976
# Epoch 222/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0322 - accuracy: 0.9981
# Epoch 223/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0283 - accuracy: 0.9987
# Epoch 224/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0252 - accuracy: 0.9989
# Epoch 225/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.5625 - accuracy: 0.8582
# Epoch 226/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.6345 - accuracy: 0.8214
# Epoch 227/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.2134 - accuracy: 0.9419
# Epoch 228/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0983 - accuracy: 0.9812
# Epoch 229/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0548 - accuracy: 0.9940
# Epoch 230/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0354 - accuracy: 0.9979
# Epoch 231/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0259 - accuracy: 0.9992
# Epoch 232/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0265 - accuracy: 0.9990
# Epoch 233/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0221 - accuracy: 0.9994
# Epoch 234/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0200 - accuracy: 0.9995
# Epoch 235/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.5596 - accuracy: 0.8689
# Epoch 236/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.7681 - accuracy: 0.7937
# Epoch 237/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.2211 - accuracy: 0.9380
# Epoch 238/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0882 - accuracy: 0.9831
# Epoch 239/250
# 399/399 [==============================] - 8s 19ms/step - loss: 0.0492 - accuracy: 0.9952
# Epoch 240/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.0375 - accuracy: 0.9976
# Epoch 241/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.0303 - accuracy: 0.9986
# Epoch 242/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.0337 - accuracy: 0.9975
# Epoch 243/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.3095 - accuracy: 0.9131
# Epoch 244/250
# 399/399 [==============================] - 8s 21ms/step - loss: 0.4742 - accuracy: 0.8601
# Epoch 245/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.1978 - accuracy: 0.9444
# Epoch 246/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.0838 - accuracy: 0.9837
# Epoch 247/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.0467 - accuracy: 0.9952
# Epoch 248/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.0325 - accuracy: 0.9976
# Epoch 249/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.0211 - accuracy: 0.9992
# Epoch 250/250
# 399/399 [==============================] - 8s 20ms/step - loss: 0.0178 - accuracy: 0.9995

# %%
# to generate randon integers
from random import randint
# to load the pickle file
from pickle import load
# loading the model from h5
from keras.models import load_model
# to provide padding for short sentences
from keras.preprocessing.sequence import pad_sequences
# to process the array
import numpy as np

# opening the file and returning it as text
def load_doc(filename):
  # opening the file in read only mode
  file= open(filename,'r')
  # extracting the text from the file
  text=file.read()
  # closing the file
  file.close()
  # returning the text
  return text

# function to generate sentences
def generate_seq(model, tokenizer,seq_length,seed_text,n_words):
  # creating a list for result
  result= list()
  # taking the input text as seed text
  in_text=seed_text
  # for the length of the number of words to be genrated 
  for _ in range(n_words):
    # encoding the words as sequences
    encoded = tokenizer.texts_to_sequences([in_text])[0]
    # padding the rest of the words
    encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre')
    # predicting the numpy argumant for the input 
    yhat = np.argmax(model.predict(encoded), axis=-1)
    # initialising the output sequence
    out_word = ''
    # converting category back to word 
    for word, index in tokenizer.word_index.items():
      if index == yhat:
        out_word = word
        break
    # appending the text that is generated
    in_text += ' ' + out_word
    # forming the result
    result.append(out_word)
  # returning the result
  return ' '.join(result)

# providing the input file
in_filename = 'sequences.txt'
# loading the document
doc = load_doc(in_filename)
#splitting it into lines
lines = doc.split('\n')
# creating the sequence length
seq_length = len(lines[0].split()) - 1

#loading the predictive model
model = load_model('model.h5')
 
# load the tokenizer
tokenizer = load(open('tokenizer.pkl', 'rb'))
 
# select a seed text
#seed_text = lines[randint(0,len(lines))]
#if you want to provide your own input just uncomment the below line and put your own input inside the ''.
seed_text = 'I do not know whether Papa guessed my feelings on the subject, probably not, and in any case he would not have been interested. The opinion of other people never interested him in the slightest degree. I think it was really a sign of his greatness. In the same way, he lived quite detached from the necessities of daily life. He ate what was put before him in an exemplary fashion, but seemed mildly pained when the question of paying'
print(seed_text + '\n')
 
# generate new text
generated = generate_seq(model, tokenizer, seq_length, seed_text, 50)
print("generated text:",generated)
# Out:
# I do not know whether Papa guessed my feelings on the subject, probably not, and in any case he would not have been interested. The opinion of other people never interested him in the slightest degree. I think it was really a sign of his greatness. In the same way, he lived quite detached from the necessities of daily life. He ate what was put before him in an exemplary fashion, but seemed mildly pained when the question of paying
#
# generated text: there poirot only a yacht he is not there is it of my friend returned poirot wheeled to proceed to her with us asked he was half about within the day he handed it with me a little troubled a tall visitors were stolen and a bit different which he
